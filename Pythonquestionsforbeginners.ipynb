# %% [markdown]
# #**Python Question Set**

# %% [markdown]
# This prep kit is designed for beginners who want to learn Python through coding practice. The questions move from basic to advanced beginner level and cover:
# - Python Basics
# - Input/Output
# - Operators
# - Conditional Statements
# - Loops
# - Strings
# - Lists
# - Tuples
# - Dictionaries
# - Sets
# - Functions
# - File Handling
# - OOP Basics
# - Exception Handling
# - Mini Logic Building

# %% [markdown]
# #**Python Basics**

# %%
#Ques1 - Print "Hello World" in Python.
print("Hello World!")
# Out:
# Hello World!

# %%
#Ques2- Take user name as input and print a welcome message.
name=input("Enter your name: ")
print("Welcome",name)

# %%
#Ques3- Add two numbers entered by the user.
num1=int(input("Enter Number 1: "))
num2=int(input("Enter Number 2: "))
sum=num1+num2
print("Sum of two numbers =",sum)

# %%
#Ques4- Find Area of a rectangle.
length=int(input("Enter length of the rectangle: "))
breadth=int(input("Enter breadth of the rectangle: "))
area=length*breadth
print(f"Area of the rectangle is {area}cm\u00b2.")

# %%
#Ques5- Convert temperature from Celsius to Fahrenheit.
celsius=int(input("Enter temperature in Celsius: "))
Fahrenheit=(celsius*9/5)+32
print(f"{celsius}℃ is equal to {Fahrenheit}℉.")

# %%
#Ques6- Swap two variables using a third variable.
a=int(input("Enter Variable 1: "))
b=int(input("Enter Variable 2: "))
print(f"Before Swapping: a={a} & b={b}")
c=a
a=b
b=c
print(f"After Swapping: a={a} & b={b}")

# %%
#Ques7- Find the square of a number.
a=int(input("Enter a number: "))
print(f"Square of {a} is {a**2}.")

# %%
#Ques8- Check the datatype of different variables.
a=15 #int
b="Hello" #string
c=15.5 #float
d= True #bool
e=[1,2,3] #list
f=(1,2,3) #tuple
g={1,2,3} #set
h={"a":1,"b":2} #dict
i=3+4j #complex
print(f"Datatype of a is {type(a)}")
print(f"Datatype of b is {type(b)}")
print(f"Datatype of b is {type(c)}")
print(f"Datatype of b is {type(d)}")
print(f"Datatype of b is {type(e)}")
print(f"Datatype of b is {type(f)}")
print(f"Datatype of b is {type(g)}")
print(f"Datatype of b is {type(h)}")
print(f"Datatype of b is {type(i)}")

# %%
#Ques9- Convert integer to float and float to integer.
a=15 #int
print(float(a))

# %%
#Ques10- Find the remainder when two numbers are divided.
a=int(input("Enter Dividend : "))
b=int(input("Enter Divisor : "))
print(f"Remainder when {a} is divided by {b} is {a%b}.")

# %%
#Ques11- Calculate simple interest.
p=float(input("Enter the Principle amount: "))
r=float(input("Enter the rate of interest: "))
t=float(input("Enter the time period: "))
si=(p*r*t)/100
print(f"Simple Interest = {si}")

# %%
#Ques12- Swap two variables without using third variable.
a=int(input("Enter Variable 1: "))
b=int(input("Enter Variable 2: "))
print(f"Before Swapping: a={a} & b={b}")
a=a+b
b=a-b
a=a-b
print(f"After Swapping: a={a} & b={b}")

# %%
#Ques13- Calculate compound interest.
p=float(input("Enter the Principle amount: "))
r=float(input("Enter the rate of interest: "))
t=float(input("Enter the time period: "))
n=float(input("Enter the number of times interest is compounded per time period: "))
amount = p * (1 + (r / (100 * n))) ** (n * t)
interest = amount - p
print(f"Compound Interest = {interest:.2f}")
print(f"Amount = {amount:.2f}")

# %%
#Ques14- Average of 5 Numbers.
sum=0
for i in range(5):
    num = float(input(f"Enter number {i+1}: "))
    sum+=num
avg=sum/5
print(f"Average of 5 numbers = {avg:.2f}")

# %%
#Ques15- Convert minutes into hours and minutes.
total_minutes = int(input("Enter the number of minutes: "))
hours = total_minutes // 60 #divides the number
minutes = total_minutes % 60 #gives remainder
print(f"{hours}:{minutes:02d}")

# %% [markdown]
# ##**Conditional Statements**

# %%
#Ques16- Check whether a number is even or odd.
num=int(input("Enter a number: "))
if num%2==0:
    print(f"{num} is an even number.")
else:
    print(f"{num} is an odd number.")

# %%
#Ques17-Check whether a number is positive, negative, or zero.
num=int(input("Enter a number: "))
if num>0:
    print(f"{num} is a positive number.")
elif num<0:
    print(f"{num} is a negative number.")
else:
    print(f"{num} is zero.")

# %%
#Ques18- Find the largest of two numbers
num1=int(input("Enter Number 1: "))
num2=int(input("Enter Number 2: "))
if num1>num2:
    print(f"{num1} is greater than {num2}.")
else:
    print(f"{num2} is greater than {num1}.")

# %%
#Ques19- Find the largest of 3 numbers
num1=int(input("Enter Number 1: "))
num2=int(input("Enter Number 2: "))
num3=int(input("Enter Number 3: "))
if num1>num2 and num1>num3:
    print(f"{num1} is greater than {num2} and {num3}.")
elif num2>num1 and num2>num3:
    print(f"{num2} is greater than {num1} and {num3}.")
else:
    print(f"{num3} is greater than {num1} and {num2}.")

# %%
#Ques20- Check whether a year is a leap year.
year=int(input("Enter a year: "))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("Leap year")
        else:
            print("Not a leap year")
    else:
        print("Leap year")
else:
    print("Not a leap year")

# %%
#Ques21- Check whether a number is divisible by 5 and 11.
num=int(input("Enter a number: "))
if num%5==0 and num%11==0:
  print(f"{num} is divisible by 5 and 11")
else:
  print(f"{num} is not divisible by 5 and 11")

# %%
#Ques22- Check whether a character is a vowel or consonant.
ch=input("Enter a character: ")
if ch.lower() in ['a','e','i','o','u']:
    print(f"{ch} is a vowel.")
else:
    print(f"{ch} is a consonant.")

# %%
#Ques23- Check whether a person is eligible to vote.
age=int(input("Enter your age: "))
if age>18:
  print("You are eligible to vote.")
else:
  print("You are not eligible to vote.")

# %%
#Ques24- Calculate electricity bill using conditions.
'''0–50 Units: Units × ₹3.21
51–100 Units: (50 × ₹3.21) + (Remaining units × ₹4.67)
101–200 Units: (50 × ₹3.21) + (50 × ₹4.67) + (Remaining units × ₹6.66)
>200 Units: (50 × ₹3.21) + (50 × ₹4.67) + (100 × ₹6.66) + (Remaining units × ₹8.50)'''
units=int(input("Enter the number of units consumed: "))
if units<=50:
  bill=units*3.21
elif units<=100:
  bill=(50*3.21)+(units-50)*4.6
elif units<=200:
  bill=(50*3.21)+(50*4.6)+((units-100)*6.6)
else:
  bill=(50*3.21)+(50*4.6)+(100*6.6)+((units-200)*8.5)
print(f"Electricity bill = ₹{bill:.2f}")

# %%
#Ques25- Create a simple calculator using if-else.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Enter operator (+, -, *, /): ")

if op == '+':
    print("Result:", num1 + num2)
elif op == '-':
    print("Result:", num1 - num2)
elif op == '*':
    print("Result:", num1 * num2)
elif op == '/':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error! Division by zero.")
else:
    print("Invalid operator.")

# %%
#Ques26- Find profit or loss percentage.
cp=float(input("Enter the cost price: "))
sp=float(input("Enter the selling price: "))
if sp>cp:
  profit=(sp-cp)/cp*100
  print(f"Profit percentage = {profit:.2f}%")
elif sp<cp:
  loss=(cp-sp)/cp*100
  print(f"Loss percentage = {loss:.2f}%")
else:
  print("No profit no loss.")

# %%
#Ques27- Check whether a number is a multiple of 3 and 7.
num=int(input("Enter a number: "))
if num%21==0:
  print(f"{num} is a multiple of 3 and 7.")
else:
  print(f"{num} is not a multiple of 3 and 7.")

# %%
#Ques28- Assign grades based on marks.
marks = float(input("Enter marks: "))
if marks >= 90:
    grade = 'A'
elif marks >= 80:
    grade = 'B'
elif marks >= 70:
    grade = 'C'
elif marks >= 60:
    grade = 'D'
else:
    grade = 'F'

print(f"Your grade is: {grade}")

# %%
#Ques29- Find whether a character is uppercase or lowercase.
ch=input("Enter a character: ")
if ch.isupper():
  print(f"{ch} is an uppercase character.")
elif ch.islower():
  print(f"{ch} is a lowercase character.")

# %%
#Ques30- Check whether a triangle is valid or not.
side1=int(input("Enter side 1: "))
side2=int(input("Enter side 2: "))
side3=int(input("Enter side 3: "))
if side1+side2>side3 and side1+side3>side2 and side2+side3>side1:
  print("Triangle is valid.")
else:
  print("Triangle is not valid.")

# %% [markdown]
# #**Loops**

# %%
#Ques31- Print numbers from 1 to 100.
for i in range(1,101):
  print(f"{i:<3}",end=" ")
  if i%10==0:
    print()

# %%
#Ques32- Print even numbers from 1 to 100.
for i in range(1,101):
  if i%2==0:
    print(f"{i:<3}",end=" ")
    if i%10==0:
      print()

# %%
#Ques33- Print odd numbers from 1 to 100.
count = 0
for i in range(1, 101):
    if i % 2 != 0:
        print(f"{i:<4}", end="")
        count += 1
        # Create a new line after every 10 odd numbers printed
        if count % 5 == 0:
            print()

# %%
#Ques34- Find the sum of first N natural numbers.
sum=0
n=int(input("Enter the value of N: "))
for i in range(1,n+1):
  sum+=i
print(f"The sum of first N natural numbers is {sum}")

# %%
#Ques35- Find factorial of a number.
n=int(input("Enter the number: "))
fact=1
for i in range(1,n+1):
  fact*=i
print(f"The factorial of {n} is {fact}")

# %%
#Ques36- Print multiplication table of a number.
n=int(input("Enter the number: "))
for i in range(1,11):
  print(f"{n} x {i} = {n*i}")

# %%
#Ques37- Reverse a number.
num=int(input("Enter the number: "))
rev=0
while num>0:
  digit=num%10
  rev=rev*10+digit
  num//=10
print(f"The reverse of the number is {rev}")

# %%
#Ques38- Count digits in a number.
num=int(input("Enter the number: "))
count=0
while num>0:
  num//=10
  count+=1
print(f"The number of digits in the number is {count}")

# %%
#Ques39- Find sum of digits of a number.
sum=0
num=int(input("Enter the number: "))
while num>0:
  digit=num%10
  sum+=digit
  num//=10
print(f"The number of digits in the number is {sum}")

# %%
#Ques40- Check whether a number is palindrome.
rev=0
num=int(input("Enter the number: "))
temp=num
while num>0:
  digit=num%10
  rev=rev*10+digit
  num//=10
if temp==rev:
  print(f"{temp} is a palindrome number.")

# %%
#Ques41- Check whether a number is Armstrong.
num=int(input("Enter the number: "))
temp=num
sum=0
while temp>0:
  sum=sum+((temp%10)**3)
  temp=temp//10
if sum==num:
  print("Armstrong number", num)
else:
  print("Not an Armstrong number",num)

# %%
#Ques42- Print Fibonacci series.
n=int(input("Enter the number of terms: "))
a,b=0,1
for _ in range(n):
  print(a,end=" ")
  a,b=b,a+b

# %%
#Ques43- Find HCF of two numbers.
num1=int(input("Enter the first number: "))
num2=int(input("Enter the second number: "))
while num2!=0:
  temp=num2
  num2=num1%num2
  num1=temp
print(f"The HCF of {num1} and {num2} is {num1}")

# %%
#Ques44- Find LCM Of two numbers.
num1=int(input("Enter the first number: "))
num2=int(input("Enter the second number: "))
temp1=num1
temp2=num2
while num2!=0:
  temp=num2
  num2=num1%num2
  num1=temp
lcm=(temp1*temp2)//num1
print

# %%
#Ques45- Check whether a number is prime.
num = int(input("Enter the number: "))
if num <= 1:
    print(f"{num} is not a prime number")
else:
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            print(f"{num} is not a prime number")
            break
    else:
        print(f"{num} is a prime number")

# %% [markdown]
# #**Pattern Questions**

# %%
#Ques46- Print Square Pattern.
n=int(input("Enter the number of rows: "))
for i in range(n):
  for j in range(n):
    print("*",end=" ")
  print()

# %%
#Ques47- Print right triangle pattern.
n=int(input("Enter the number of rows: "))
for i in range(1,n+1):
  print('*'*i)

# %%
#Ques48- Print inverted triangle pattern.
n=int(input("Enter the number of rows: "))
for i in range(n, 0, -1):
        print(' ' * (n - i), end='')
        print('*' * (2 * i - 1))

# %%
#Ques49- Print pyramid pattern.
n=int(input("Enter the number of rows: "))
for i in range(1, n+1):
        print(' ' * (n - i), end='')
        print('*' * (2 * i - 1))

# %%
#Ques50- Print Floyd’s triangle.
rows = int(input("Enter the number of rows: "))
num = 1
for i in range(1, rows + 1):
    for j in range(1, i + 1):
        print(num, end=" ")
        num += 1
    print()

# %%
#Ques51- Print diamond pattern.
num=int(input("Enter the number of rows: "))
for i in range(1,num+1):
  print(' '*(num-i),end='')
  print('*'*(2*i-1))
for i in range(num-1,0,-1):
  print(' '*(num-i),end='')
  print('*'*(2*i-1))

# %%
#Ques52- Print alphabet triangle pattern.
n = int(input("Enter the number of rows: "))
for i in range(1, n + 1):
    print((chr(64 + i) + " ") * i)

# %%
#Ques53- Print number pyramid pattern.
n = int(input("Enter the number of rows: "))
for i in range(1, n + 1):
    print(" " * (n - i), end="")
    for j in range(1, i + 1):
        print(j, end=" ")
    for j in range(i - 1, 0, -1):
        print(j, end=" ")
    print()

# %%
#Ques54- Print hollow square pattern.
n=int(input("Enter the size of the square: "))
for i in range(n):
    for j in range(n):
        if i == 0 or i == n - 1 or j == 0 or j == n- 1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()

# %%
#Ques55- Print Pascal’s triangle.
rows = int(input("Enter number of rows: "))
for i in range(rows):
    for j in range(rows - i - 1):
        print(" ", end=" ")
    num = 1
    for j in range(i + 1):
        print(num, end="   ")
        num = num * (i - j) // (j + 1)
    print()

# %% [markdown]
# #**Strings**

# %%
#Ques56- Find the length of a string
my_str=input("Enter the String: ")
print(len(my_str))

# %%
#Ques57- Reverse a string.
my_str=input("Enter the String: ")
rev_str=my_str[::-1]
print(f"The reverse of {my_str} is {rev_str}")

# %%
#Ques58- Check whether a string is palindrome.
my_str=input("Enter the String: ")
if my_str==my_str[::-1]:
  print(f"{my_str} is a palindrome string.")
else:
  print(f"{my_str} is not a palindrome string.")

# %%
#Ques59-Count vowels and consonants in a string.
my_str = input("Enter the String: ")
vowels = "aeiouAEIOU"
vowel_count = 0
consonant_count = 0
for char in my_str:
    if char.isalpha():
        if char in vowels:
            vowel_count += 1
        else:
            consonant_count += 1
print(f"Number of vowels: {vowel_count}")
print(f"Number of consonants: {consonant_count}")

# %%
#Ques60- Convert string to uppercase and lowercase.
my_str = input("Enter the String: ")
print(my_str.upper())
print(my_str.lower())

# %%
#Ques61- Count frequency of characters in a string.
my_str = input("Enter the String: ")
d={}
for char in my_str:
  d[char]=d.get(char,0)+1
print(d)

# %%
#Ques62- Remove spaces from a string.
my_str=input("Enter the String: ")
print(my_str.replace(" ",""))

# %%
#Ques63-Find whether a substring exists in a string.
my_str=input("Enter the String: ")
sub_str=input("Enter the substring: ")
if sub_str in my_str:
  print(f"{sub_str} exists in string.")
else:
  print(f"{sub_str} does not exist in string.")

# %%
#Ques64- Replace a word in a string.
my_str=input("Enter the String: ")
old_word=input("Enter the old word: ")
new_word=input("Enter the new word: ")
print(my_str.replace(old_word,new_word))

# %%
#Ques65- Count Words in a sentence.
sentence = input("Enter a sentence: ")
words = sentence.split()
word_count = len(words)
print(f"The number of words in the sentence is: {word_count}")

# %%
#Ques66- Find duplicate characters in a string.
string = input("Enter a string: ")
freq = {}
for ch in string:
    if ch != " ":
        freq[ch] = freq.get(ch, 0) + 1
print("Duplicate characters:")
for key, value in freq.items():
    if value > 1:
        print(key, ":", value)

# %%
#Ques67- Sort words in alphabetical order.
my_str=input("Enter the String: ")
words=my_str.split()
words.sort()
print(words)

# %%
#Ques68- Find ASCII value of a character.
char= input("Enter the character: ")
print(ord(char))

# %%
#Ques69- Check whether two strings are anagrams.
str1=input("Enter the string: ")
str2=input("Enter the second string: ")
if sorted(str1)==sorted(str2):
  print("Anagrams")
else:
  print("Not Anagrams")

# %%
#Ques70- Find the most repeated character in a string.
from collections import Counter
my_str=input("Enter the String: ")
freq=Counter(my_str)
print(max(freq, key=freq.get))

# %% [markdown]
# #**LIST**

# %%
#Ques71- Create a list and print all elements.
lst=[1,2,3,4,5]
print(lst)

# %%
#Ques72- Find the largest element in a list.
my_list = [10, 24, 76, 23, 12]
largest = max(my_list)
print(f"The largest element in the given list is {largest}")

# %%
#Ques73- Find the smallest element in a lsit.
my_list = [10, 24, 76, 23, 12]
smallest= min(my_list)
print(f"The smallest element in the given list is {smallest}")

# %%
#Ques74- Find the sum of all the elements in the list.
my_list = [10, 24, 76, 23, 12]
total_sum=sum(my_list)
print(f"The sum of all the elements in the given list is {total_sum}")

# %%
#Ques75- Remove duplicates from the list.
my_list = [10, 24, 76, 23, 12 ,10 ,17 ,24 ,12 ]
print(set(my_list))

# %%
#Ques76- Sort a list in ascending order.
my_list = [10, 24, 76, 23, 12]
sorted_lst=my_list.sort()
print(my_list)

# %%
#Ques77- Sort a list in descending order.
my_list = [10, 24, 76, 23, 12]
print(sorted(my_list,reverse=True))

# %%
#Ques78- Find second largest number in a list.
my_list = [10, 24, 76, 23, 12]
sorted_list=my_list.sort()
print(my_list[-2])

# %%
#Ques79- Merge two lists.
lst1=[1,2,4,5,7,8]
lst2=[7,8,9,12,2,99]
new_lst=lst1+lst2
print(new_lst)

# %%
#Ques80- Find common elements between two lists.
a = [1, 2, 3, 4, 5]
b = [4, 5, 6, 7, 8]
res = list(set(a) & set(b))
print(res)

# %% [markdown]
# #**Tuples, Sets & Dictionaries**

# %%
#Ques81- Create and access tuple elements.
my_tuple=(1,2,3,4)
print(my_tuple)

# %%
#Ques82- Convert tuple into list.
my_tuple=(1,2,3,4)
tuple_to_lst=list(my_tuple)
print(tuple_to_lst)

# %%
#Ques83- Count frequency of elements using dictionary.
data = ['apple', 'banana', 'apple', 'orange', 'banana', 'banana']
frequency = {}
for item in data:
    if item in frequency:
        frequency[item] += 1
    else:
        frequency[item] = 1
print(frequency)

# %%
#Ques84- Merge two dictionaries.
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}
merged_dict = dict1.copy()
for key, value in dict2.items():
    if key in merged_dict:
        merged_dict[key] += value
    else:
        merged_dict[key] = value
print(merged_dict)

# %%
#Ques85- Find key with maximum value in dictionary.
my_dict = {'a': 10, 'b': 25, 'c': 15}
max_key = max(my_dict, key=my_dict.get)
print("Key with maximum value:", max_key)

# %%
#Ques86- Remove duplicates using set
my_list = [1, 2, 2, 3, 4, 4, 5]
unique_list = list(set(my_list))
print("List after removing duplicates:", unique_list)

# %%
#Ques87- Perform union and intersection of sets
s1={1,2,3,4,5}
s2={4,5,6,7,8}
union_set=s1|s2
intersection_set=s1&s2
print("Union:", union_set)
print("Intersection:", intersection_set)

# %%
#Ques88- Create a student dictionary and display details
student = {
    "name": "Shakshi",
    "age": 22,
    "course": "MCA",
    "marks": 92
}
print("Student Details")
for key, value in student.items():
    print(key, ":", value)

# %% [markdown]
# #**Functions**

# %%
#Ques89- Create a function to add two numbers.
def add_two_num(num1,num2):
  return num1+num2

add_two_num(45,23)

# %%
#Ques90- Create a function to check prime number.
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

is_prime(11)

# %%
#Ques91- Create a recursive function for factorial.
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

print(factorial(5))

# %%
#Ques92- Create a function to find Fibonacci series.
def fibonacci(n,a=0,b=1):
  if n<=0:
    return[]
  elif n==1:
    return[0]
  series=[0,1]

  while len(series) < n:
    next_term = series[-1] + series[-2]
    series.append(next_term)
  return series

print(fibonacci(10))

# %%
#Ques93- Use lambda function to square a number.
square=lambda x:x**2
print(square(5))

# %%
#Ques94- Use map() to double list elements.
my_lst=[1,2,3,4,5]
double_lst=map(lambda x:x*2,my_lst)
print(list(double_lst))

# %% [markdown]
# #**File Handling & Exception Handling**

# %%
#Ques95-Create and write data into a text file.
file = open("my_text_file.txt", "w")
file.write("Hello, this is my first text file.\n")
file.write("And today we are studying python file handling.")
file.close()

# %%
#Ques96- Read content from a text file.
file=open("my_text_file.txt", "r")
content=file.read()
print(content)

# %%
#Ques97- Count number of words in a file.
count=0
file=open("my_text_file.txt", "r")
content=file.read()
words=content.split()
count+=len(words)
print("Total Words:" ,count)

# %%
#Ques98- Handle divide-by-zero exception using try-except.
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    result = num1 / num2
    print("Result =", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero")

# %% [markdown]
# #**OOP & Mini Projects**

# %%
#Ques99- Create a Student class with attributes and methods.
class Student:
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks


    def display(self):
        print("Student Name:", self.name)
        print("Age:", self.age)
        print("Marks:", self.marks)

s1 = Student("Shakshi", 22, 95)
s1.display()

# %%
#Ques100- Build a simple ATM system using Python.
# Simple ATM System

balance = 10000

while True:
    print("\n===== ATM MENU =====")
    print("1. Check Balance")
    print("2. Deposit Money")
    print("3. Withdraw Money")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        print("Current Balance = ₹", balance)

    elif choice == 2:
        deposit = float(input("Enter deposit amount: ₹"))
        balance += deposit
        print("Amount Deposited Successfully")
        print("Updated Balance = ₹", balance)

    elif choice == 3:
        withdraw = float(input("Enter withdrawal amount: ₹"))

        if withdraw <= balance:
            balance -= withdraw
            print("Withdrawal Successful")
            print("Remaining Balance = ₹", balance)
        else:
            print("Insufficient Balance")

    elif choice == 4:
        print("Thank you for using ATM")
        break

    else:
        print("Invalid Choice")
